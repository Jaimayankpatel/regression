# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("c:/pokemon.csv")
dataset
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
dataset.columns = dataset.columns.str.lower()
dataset.head()
# Out:
#    #                   name type 1  type 2  total  hp  attack  defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    sp. atk  sp. def  speed  generation  legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
dataset.rename(columns={'#':'sr'}, inplace=True)
dataset.rename(columns={'type 1': 'primary'}, inplace=True)
dataset.rename(columns={'type 2': 'secondary'}, inplace=True)
dataset.rename(columns={'sp. atk':'special_attack'}, inplace=True)
dataset.rename(columns={'sp. def':'special_def'}, inplace=True)
dataset.head()
# Out:
#    sr                   name primary secondary  total  hp  attack  defense  \
# 0   1              Bulbasaur   Grass    Poison    318  45      49       49
# 1   2                Ivysaur   Grass    Poison    405  60      62       63
# 2   3               Venusaur   Grass    Poison    525  80      82       83
# 3   3  VenusaurMega Venusaur   Grass    Poison    625  80     100      123
# 4   4             Charmander    Fire       NaN    309  39      52       43
#
#    special_attack  special_def  speed  generation  legendary
# 0              65           65     45           1      False
# 1              80           80     60           1      False
# 2             100          100     80           1      False
# 3             122          120     80           1      False
# 4              60           50     65           1      False

# %%
dataset.drop_duplicates('sr',keep='first',inplace=True)
dataset.head(10)
# Out:
#     sr        name primary secondary  total  hp  attack  defense  \
# 0    1   Bulbasaur   Grass    Poison    318  45      49       49
# 1    2     Ivysaur   Grass    Poison    405  60      62       63
# 2    3    Venusaur   Grass    Poison    525  80      82       83
# 4    4  Charmander    Fire       NaN    309  39      52       43
# 5    5  Charmeleon    Fire       NaN    405  58      64       58
# 6    6   Charizard    Fire    Flying    534  78      84       78
# 9    7    Squirtle   Water       NaN    314  44      48       65
# 10   8   Wartortle   Water       NaN    405  59      63       80
# 11   9   Blastoise   Water       NaN    530  79      83      100
# 13  10    Caterpie     Bug       NaN    195  45      30       35
#
#     special_attack  special_def  speed  generation  legendary
# 0               65           65     45           1      False
# 1               80           80     60           1      False
# 2              100          100     80           1      False
# ...

# %%
dataset["secondary"].fillna(value="None", inplace=True)
dataset.head(10)
# Out:
#     sr        name primary secondary  total  hp  attack  defense  \
# 0    1   Bulbasaur   Grass    Poison    318  45      49       49
# 1    2     Ivysaur   Grass    Poison    405  60      62       63
# 2    3    Venusaur   Grass    Poison    525  80      82       83
# 4    4  Charmander    Fire      None    309  39      52       43
# 5    5  Charmeleon    Fire      None    405  58      64       58
# 6    6   Charizard    Fire    Flying    534  78      84       78
# 9    7    Squirtle   Water      None    314  44      48       65
# 10   8   Wartortle   Water      None    405  59      63       80
# 11   9   Blastoise   Water      None    530  79      83      100
# 13  10    Caterpie     Bug      None    195  45      30       35
#
#     special_attack  special_def  speed  generation  legendary
# 0               65           65     45           1      False
# 1               80           80     60           1      False
# 2              100          100     80           1      False
# ...

# %%
dataset["secondary"].fillna(value="None", inplace=True)
#dataset.describe()

dataset.groupby(["primary"]).size()
# Out:
# primary
# Bug          63
# Dark         28
# Dragon       24
# Electric     36
# Fairy        17
# Fighting     25
# Fire         47
# Flying        3
# Ghost        23
# Grass        66
# Ground       30
# Ice          23
# Normal       93
# Poison       28
# Psychic      47
# Rock         41
# Steel        22
# Water       105
# dtype: int64

# %%
grass_pokemon = dataset[dataset["primary"] == "Grass"]
grass_pokemon
# Out:
#       sr        name primary secondary  total   hp  attack  defense  \
# 0      1   Bulbasaur   Grass    Poison    318   45      49       49
# 1      2     Ivysaur   Grass    Poison    405   60      62       63
# 2      3    Venusaur   Grass    Poison    525   80      82       83
# 48    43      Oddish   Grass    Poison    320   45      50       55
# 49    44       Gloom   Grass    Poison    395   60      65       70
# ..   ...         ...     ...       ...    ...  ...     ...      ...
# 718  650     Chespin   Grass      None    313   56      61       65
# 719  651   Quilladin   Grass      None    405   61      78       95
# 720  652  Chesnaught   Grass  Fighting    530   88     107      122
# 740  672      Skiddo   Grass      None    350   66      65       48
# 741  673      Gogoat   Grass      None    531  123     100       62
#
#      special_attack  special_def  speed  generation  legendary
# 0                65           65     45           1      False
# ...

# %%
water_pokemon = dataset[dataset["primary"] == "Water"]
water_pokemon
# Out:
#       sr       name primary secondary  total  hp  attack  defense  \
# 9      7   Squirtle   Water      None    314  44      48       65
# 10     8  Wartortle   Water      None    405  59      63       80
# 11     9  Blastoise   Water      None    530  79      83      100
# 59    54    Psyduck   Water      None    320  50      52       48
# 60    55    Golduck   Water      None    500  80      82       78
# ..   ...        ...     ...       ...    ...  ..     ...      ...
# 724  656    Froakie   Water      None    314  41      56       40
# 725  657  Frogadier   Water      None    405  54      63       52
# 726  658   Greninja   Water      Dark    530  72      95       67
# 762  692  Clauncher   Water      None    330  50      53       62
# 763  693  Clawitzer   Water      None    500  71      73       88
#
#      special_attack  special_def  speed  generation  legendary
# 9                50           64     43           1      False
# ...

# %%
fire_pokemon = dataset[dataset["primary"] == "Fire"]
fire_pokemon
# Out:
#       sr                     name primary secondary  total   hp  attack  \
# 4      4               Charmander    Fire      None    309   39      52
# 5      5               Charmeleon    Fire      None    405   58      64
# 6      6                Charizard    Fire    Flying    534   78      84
# 42    37                   Vulpix    Fire      None    299   38      41
# 43    38                Ninetales    Fire      None    505   73      76
# 63    58                Growlithe    Fire      None    350   55      70
# 64    59                 Arcanine    Fire      None    555   90     110
# 83    77                   Ponyta    Fire      None    410   50      85
# 84    78                 Rapidash    Fire      None    500   65     100
# 135  126                   Magmar    Fire      None    495   65      95
# 147  136                  Flareon    Fire      None    525   65     130
# 158  146                  Moltres    Fire    Flying    580   90     100
# ...

# %%
#Filter out POISION type pokemon/s from grass_pokemon

grass_poison_pokemon = grass_pokemon[grass_pokemon['secondary'] == 'Poison']
grass_poison_pokemon
# Out:
#       sr        name primary secondary  total   hp  attack  defense  \
# 0      1   Bulbasaur   Grass    Poison    318   45      49       49
# 1      2     Ivysaur   Grass    Poison    405   60      62       63
# 2      3    Venusaur   Grass    Poison    525   80      82       83
# 48    43      Oddish   Grass    Poison    320   45      50       55
# 49    44       Gloom   Grass    Poison    395   60      65       70
# 50    45   Vileplume   Grass    Poison    490   75      80       85
# 75    69  Bellsprout   Grass    Poison    300   50      75       35
# 76    70  Weepinbell   Grass    Poison    390   65      90       50
# 77    71  Victreebel   Grass    Poison    490   80     105       65
# 344  315     Roselia   Grass    Poison    400   50      60       45
# 451  406       Budew   Grass    Poison    280   40      30       35
# 452  407    Roserade   Grass    Poison    515   60      70       65
# 651  590     Foongus   Grass    Poison    294   69      55       45
# ...

# %%
grass_poison_pokemon.describe()
# Out:
#                sr       total          hp      attack    defense  \
# count   14.000000   14.000000   14.000000   14.000000  14.000000
# mean   189.785714  399.000000   63.785714   68.428571  58.214286
# std    222.461121   86.842917   19.407289   19.492461  15.967171
# min      1.000000  280.000000   40.000000   30.000000  35.000000
# 25%     43.250000  318.500000   50.000000   56.250000  46.000000
# 50%     69.500000  397.500000   60.000000   67.500000  59.000000
# 75%    383.250000  483.500000   73.500000   81.500000  68.750000
# max    591.000000  525.000000  114.000000  105.000000  85.000000
#
#        special_attack  special_def      speed  generation
# count       14.000000    14.000000  14.000000   14.000000
# mean        84.642857    72.142857  51.785714    2.142857
# std         21.073524    20.164161  20.532071    1.657484
# min         50.000000    30.000000  15.000000    1.000000
# 25%         71.250000    65.000000  40.000000    1.000000
# ...

# %%
water_psychic_pokemon = water_pokemon[water_pokemon['secondary'] == 'Psychic']
water_psychic_pokemon
# Out:
#       sr      name primary secondary  total  hp  attack  defense  \
# 85    79  Slowpoke   Water   Psychic    315  90      65       65
# 86    80   Slowbro   Water   Psychic    490  95      75      110
# 130  121   Starmie   Water   Psychic    520  60      75       85
# 214  199  Slowking   Water   Psychic    490  95      75       80
#
#      special_attack  special_def  speed  generation  legendary
# 85               40           40     15           1      False
# 86              100           80     30           1      False
# 130             100           85    115           1      False
# 214             100          110     30           2      False

# %%
water_psychic_pokemon.describe()
# Out:
#                sr       total         hp  attack     defense  special_attack  \
# count    4.000000    4.000000   4.000000     4.0    4.000000             4.0
# mean   119.750000  453.750000  85.000000    72.5   85.000000            85.0
# std     56.340483   93.574836  16.832508     5.0   18.708287            30.0
# min     79.000000  315.000000  60.000000    65.0   65.000000            40.0
# 25%     79.750000  446.250000  82.500000    72.5   76.250000            85.0
# 50%    100.500000  490.000000  92.500000    75.0   82.500000           100.0
# 75%    140.500000  497.500000  95.000000    75.0   91.250000           100.0
# max    199.000000  520.000000  95.000000    75.0  110.000000           100.0
#
#        special_def       speed  generation
# count     4.000000    4.000000        4.00
# mean     78.750000   47.500000        1.25
# std      28.975564   45.552168        0.50
# min      40.000000   15.000000        1.00
# 25%      70.000000   26.250000        1.00
# ...

# %%
fire_fighting_pokemon = fire_pokemon[fire_pokemon['secondary'] == 'Fighting']
fire_fighting_pokemon
# Out:
#       sr       name primary secondary  total   hp  attack  defense  \
# 277  256  Combusken    Fire  Fighting    405   60      85       60
# 278  257   Blaziken    Fire  Fighting    530   80     120       70
# 436  391   Monferno    Fire  Fighting    405   64      78       52
# 437  392  Infernape    Fire  Fighting    534   76     104       71
# 558  499    Pignite    Fire  Fighting    418   90      93       55
# 559  500     Emboar    Fire  Fighting    528  110     123       65
#
#      special_attack  special_def  speed  generation  legendary
# 277              85           60     55           3      False
# 278             110           70     80           3      False
# 436              78           52     81           4      False
# 437             104           71    108           4      False
# 558              70           55     55           5      False
# 559             100           65     65           5      False

# %%
fire_fighting_pokemon.describe()
# Out:
#                sr       total          hp      attack    defense  \
# count    6.000000    6.000000    6.000000    6.000000   6.000000
# mean   382.500000  470.000000   80.000000  100.500000  62.166667
# std    108.897658   66.654332   18.286607   18.447222   7.833688
# min    256.000000  405.000000   60.000000   78.000000  52.000000
# 25%    290.500000  408.250000   67.000000   87.000000  56.250000
# 50%    391.500000  473.000000   78.000000   98.500000  62.500000
# 75%    472.250000  529.500000   87.500000  116.000000  68.750000
# max    500.000000  534.000000  110.000000  123.000000  71.000000
#
#        special_attack  special_def       speed  generation
# count        6.000000     6.000000    6.000000    6.000000
# mean        91.166667    62.166667   74.000000    4.000000
# std         15.854547     7.833688   20.218803    0.894427
# min         70.000000    52.000000   55.000000    3.000000
# 25%         79.750000    56.250000   57.500000    3.250000
# ...

# %%
my_first_pokemon = grass_poison_pokemon[grass_poison_pokemon["speed"] == 90]
my_first_pokemon
# Out:
#       sr      name primary secondary  total  hp  attack  defense  \
# 452  407  Roserade   Grass    Poison    515  60      70       65
#
#      special_attack  special_def  speed  generation  legendary
# 452             125          105     90           4      False

# %%
my_second_pokemon = water_psychic_pokemon[water_psychic_pokemon["defense"] ==110]
my_second_pokemon
# Out:
#     sr     name primary secondary  total  hp  attack  defense  special_attack  \
# 86  80  Slowbro   Water   Psychic    490  95      75      110             100
#
#     special_def  speed  generation  legendary
# 86           80     30           1      False

# %%
my_thired_pokemon = fire_fighting_pokemon[fire_fighting_pokemon["attack"] ==123]
my_thired_pokemon
# Out:
#       sr    name primary secondary  total   hp  attack  defense  \
# 559  500  Emboar    Fire  Fighting    528  110     123       65
#
#      special_attack  special_def  speed  generation  legendary
# 559             100           65     65           5      False

# %%
###___________________________________________________________________###

# %%
#perform the regression

# %%
x= dataset[['defense']]
x
y= dataset['attack']
y
x1=dataset["hp"]
x1
x2=dataset["speed"]
x2
# Out:
# 0      45
# 1      60
# 2      80
# 4      65
# 5      80
#        ..
# 793    99
# 794    95
# 795    50
# 797    70
# 799    70
# Name: speed, Length: 721, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=1)
x_train
y_train
x_train.shape
# Out:
# (504, 1)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(x_test)

# %%
lm.score(x_test, y_test)
# Out:
# 0.1955103603336964

# %%
plt.scatter (y_pred ,y_test)

# %%
y_test
# Out:
# 65      50
# 66      65
# 233     95
# 700    129
# 11      83
#       ...
# 647    100
# 35      62
# 691     65
# 779    110
# 589    135
# Name: attack, Length: 217, dtype: int64

# %%
y_pred=lm.predict([[6]])
y_pred
# Out:
# array([47.94704208])

# %%
plt.scatter(x_train ,y_train,color='purple')
plt.plot(x_train ,lm.predict(x_train),color='black')
plt.show()

# %%
#classification
#find out the my pokemon is lengendary or not

# %%
y = dataset['legendary']
x = dataset.drop('legendary', axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
y_train
# Out:
# 505    False
# 748    False
# 110    False
# 465    False
# 549     True
#        ...
# 525    False
# 436    False
# 310    False
# 663    False
# 757    False
# Name: legendary, Length: 540, dtype: bool

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,4))
for columns in ['hp','attack','defense','speed']:
    sns.kdeplot(dataset[columns],shade=True)
    plt.show()
